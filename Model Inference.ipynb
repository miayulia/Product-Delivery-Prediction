# %% [markdown]
# # Model Inference

# %%
import pandas as pd
import joblib

# %%
#load model
models = joblib.load(open('shipment.pkl', 'rb'))

# %%
#load data inference
inf = pd.read_csv('data_inf.csv')
inf
# Out:
#      ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0  5262               F             Ship                    6
# 1   361               D             Ship                    5
# 2  6172               B           Flight                    5
# 3  3818               F             Road                    3
# 4  7139               C           Flight                    3
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 0                4                  304                4                low
# 1                2                  246                3             medium
# 2                5                  189                3                low
# 3                4                  201               10               high
# 4                4                  180                7               high
#
#   Gender  Discount_offered  Weight_in_gms
# 0      F                 2           1749
# 1      M                49           3236
# ...

# %%
#add prediction to columns
inf['Reached.on.Time_Y.N'] = models.predict(inf)

# %%
inf
# Out:
#      ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0  5262               F             Ship                    6
# 1   361               D             Ship                    5
# 2  6172               B           Flight                    5
# 3  3818               F             Road                    3
# 4  7139               C           Flight                    3
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 0                4                  304                4                low
# 1                2                  246                3             medium
# 2                5                  189                3                low
# 3                4                  201               10               high
# 4                4                  180                7               high
#
#   Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0      F                 2           1749                    0
# ...
